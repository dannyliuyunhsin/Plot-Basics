# %% [markdown]
# ## Chapter 2 : Seaborn : 在 matplotlib 的基礎上進行更高級的 API 封裝
#
# * 需安裝套件 : `conda install seaborn`
# * 攸關畫圖的參數資訊 : 可以利用 shift + tab 鍵來了解詳細資訊
#
# `import seaborn as sns` : 使用此套件
# `%matplotlib inline` : 執行cell，即可畫圖

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 取得目前的風格
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': (1, 1, 1, 0),
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'patch.force_edgecolor': False,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
# 還原成初始風格
sns.set()

# %% [markdown]
# ### 背景style
#
# * darkgrid
# * dark
# * whitegrid
# * white
# * ticks

# %%
# 設定一個 list point_x 與 list point_y
point_x = [1,2,3,4,5]
point_y = [25,16,9,4,1]

# 設定背景格式 例: darkgrid 灰色網格
sns.set(style = "darkgrid")

plt.plot(point_x, point_y)

# %% [markdown]
# ### set_context() : 用於圖形大小的設置
#
# * paper
# * notebook(預設)
# * talk
# * poster

# %%
# 設定 point_x 與 point_y
point_x = np.arange(-180, 180)
point_y = np.sin(point_x * np.pi / 180.0)

sns.set_context('poster')
plt.plot(point_x, point_y)

# %% [markdown]
# ### 線條 style
#
# * 顏色 :
#     * `color_palette(palette=None, n_colors=None, desat=None)`
#         * palette : 調色盤
#             * deep
#             * muted
#             * pastel
#             * bright
#             * dark
#             * colorblind
#         * n_colors : n個顏色
#         * deset : 飽和度，值界在0到1之間
#     * `hls_palette(h = None, l = None, s = None)`
#         * h : 色相，0~1
#         * l : 亮度，0~1
#         * s : 飽和度，0~1

# %%
# 設定四個異常種類的數量
abnormal_num = [3, 7, 5, 10]

# 設定四個種類的標籤
label = ["abnormal_1", "abnormal_2", "abnormal_3", "abnormal_4"]

# 設定四個種類的顏色
color = ["red", "yellow", "blue", "green"]

plt.pie(abnormal_num, labels=label, colors=color)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a8dd848648>,
#   <matplotlib.patches.Wedge at 0x1a8dd850248>,
#   <matplotlib.patches.Wedge at 0x1a8dd850c48>,
#   <matplotlib.patches.Wedge at 0x1a8dd857508>],
#  [Text(1.022754137889241, 0.404936999335002, 'abnormal_1'),
#   Text(-0.06906955709217581, 1.097829402176445, 'abnormal_2'),
#   Text(-1.1, 1.3471114790620887e-16, 'abnormal_3'),
#   Text(0.3399187231970731, -1.046162158377023, 'abnormal_4')])

# %% [markdown]
# `sns.color_palette("muted", n_colors, desat)`
#
# * `'muted'` : 柔和模式
# * `n_color` : 設定要幾種顏色
# * `desat` : 飽和度

# %%
# 設定調色盤 : 柔和模式
muted_palette = sns.color_palette("muted", n_colors=15, desat=0.5)

# 顯示調色盤
sns.palplot(muted_palette)

# %%
# 設定四個異常種類的數量
abnormal_num = [3, 7, 5, 10]

# 設定四個種類的標籤
label = ["abnormal_1", "abnormal_2", "abnormal_3", "abnormal_4"]

# colors : 柔和模式
plt.pie(abnormal_num, labels=label, colors=muted_palette)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a8dd91aec8>,
#   <matplotlib.patches.Wedge at 0x1a8dd9239c8>,
#   <matplotlib.patches.Wedge at 0x1a8dd928408>,
#   <matplotlib.patches.Wedge at 0x1a8dd928e48>],
#  [Text(1.022754137889241, 0.404936999335002, 'abnormal_1'),
#   Text(-0.06906955709217581, 1.097829402176445, 'abnormal_2'),
#   Text(-1.1, 1.3471114790620887e-16, 'abnormal_3'),
#   Text(0.3399187231970731, -1.046162158377023, 'abnormal_4')])

# %% [markdown]
# `sns.hls_palette(h, l, s)`
#
# * h : 色相 (0~1)
# * l : 亮度 (0~1)
# * s : 飽和度 (0~1)

# %%
# 設定調色盤 色相、亮度、飽和度
hls_palette = sns.hls_palette(h = 0.3, l = 0.8, s = 0.7)

# 顯示調色盤
sns.palplot(hls_palette)

# %%
# 設定四個異常種類的數量
abnormal_num = [3, 7, 5, 10]

# 設定四個種類的標籤
label = ["abnormal_1", "abnormal_2", "abnormal_3", "abnormal_4"]

# colors : hls_palette
plt.pie(abnormal_num, labels=label, colors=hls_palette)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a8dd9c80c8>,
#   <matplotlib.patches.Wedge at 0x1a8dd9c8b08>,
#   <matplotlib.patches.Wedge at 0x1a8dd9cd508>,
#   <matplotlib.patches.Wedge at 0x1a8dd9cdec8>],
#  [Text(1.022754137889241, 0.404936999335002, 'abnormal_1'),
#   Text(-0.06906955709217581, 1.097829402176445, 'abnormal_2'),
#   Text(-1.1, 1.3471114790620887e-16, 'abnormal_3'),
#   Text(0.3399187231970731, -1.046162158377023, 'abnormal_4')])
